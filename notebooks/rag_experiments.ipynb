# %% [markdown]
# # Resume Analyzer (RAG) Experiments
#
# This notebook demonstrates how to load a PDF, split it into chunks, embed it using HuggingFace, and run an OpenRouter LLM query.

# %%
import os
from dotenv import load_dotenv
load_dotenv('../.env')

# Langchain Imports
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_openai import ChatOpenAI

# %% [markdown]
# ### 1. Load Resume PDF

# %%
# NOTE: Make sure a PDF exists at this path or update it
# loader = PyPDFLoader("../backend/temp/sample_resume.pdf")
# docs = loader.load()
# print(len(docs))

# %% [markdown]
# ### 2. Split Text

# %%
# splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
# chunks = splitter.split_documents(docs)
# print(len(chunks))

# %% [markdown]
# ### 3. Embeddings & Vector DB

# %%
# embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# db = FAISS.from_documents(chunks, embeddings)

# %% [markdown]
# ### 4. QA Retrieval using OpenRouter

# %%
# query = "What are the main skills listed?"
# retriever = db.as_retriever()
# relevant_docs = retriever.invoke(query)

# llm = ChatOpenAI(
#     openai_api_base="https://openrouter.ai/api/v1",
#     openai_api_key=os.getenv("OPENROUTER_API_KEY"),
#     model_name="openai/gpt-3.5-turbo" # Adjust model if needed
# )

# response = llm.invoke(f"Based on this resume context: {relevant_docs}, answer: {query}")
# print(response.content)
